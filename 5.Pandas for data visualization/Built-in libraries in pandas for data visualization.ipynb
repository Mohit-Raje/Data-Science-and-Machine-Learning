# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('df1' , index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=40 , grid=False)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist' , bins=40)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.head()
df2.count()
# Out:
# a    10
# b    10
# c    10
# d    10
# dtype: int64

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.line(x=df1.index , y='B')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [51], in <module>
# ----> 1 df1.plot.line(x=df1.index , y='B')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_core.py:1041, in PlotAccessor.line(self, x, y, **kwargs)
#     976 @Appender(
#     977     """
#     978     See Also
#    (...)
#    1033 @Appender(_bar_or_line_doc)
#    1034 def line(self, x=None, y=None, **kwargs):
#    1035     """
#    1036     Plot Series or DataFrame as lines.
#    1037
#    1038     This function is useful to plot lines using DataFrame's values
#    1039     as coordinates.
#    1040     """
# -> 1041     return self(kind="line", x=x, y=y, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_core.py:937, in PlotAccessor.__call__(self, *args, **kwargs)
#     935 if is_integer(x) and not data.columns.holds_integer():
# ...

# %%
df1.plot.scatter(x='A' , y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
